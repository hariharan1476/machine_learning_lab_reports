# %%
# !pip install soundfile matplotlib numpy

# %%
import numpy as np
import matplotlib.pyplot as plt
import soundfile as sf

audio_file = 'WhatsApp Ptt 2024-07-25 at 21.02.59.ogg'
data, samplerate = sf.read(audio_file)

plt.figure(figsize=(10, 4))
plt.plot(data)
plt.title('Audio Waveform')
plt.xlabel('Sample')
plt.ylabel('Amplitude')
plt.show()

# %%
# !pip install soundfile matplotlib numpy

# %%
import numpy as np
import matplotlib.pyplot as plt
import soundfile as sf

audio_file = 'WhatsApp Ptt 2024-07-25 at 21.02.59.ogg'
data, samplerate = sf.read(audio_file)

time = np.arange(0, len(data)) / samplerate

plt.figure(figsize=(12, 6))
plt.plot(time, data, label='Audio Waveform', color='b')

plt.title('Audio Waveform Visualization', fontsize=16)
plt.xlabel('Time (seconds)', fontsize=14)
plt.ylabel('Amplitude', fontsize=14)
plt.legend()

plt.grid(True, which='both', linestyle='--', linewidth=0.5)

plt.tight_layout()

plt.show()
